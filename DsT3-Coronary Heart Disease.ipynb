# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("Data.csv")

# %%
data.head()
# Out:
#         ID    IV  A1   A2  A3  A4  A5  A6  A7  A8  ...  A14   A15   A16  A17  \
# 0  1443894  2049  44  8.0  11   0   0   0   0  38  ...    0  0.52  0.69    0
# 1  1810849    48   0  8.0   0   0   0   0   0   1  ...    0  0.59  0.78    1
# 2  2264999   318   2  9.0   0   0   0   0   0   0  ...    0  0.94  0.79    1
# 3  1931676    62   4  2.0   0   0   0  15  30   7  ...    0  0.51  0.47    0
# 4  2070885     2   0  8.0   0   0   0   0   1   0  ...    0  0.82  0.81    0
#
#    A18  A19  A20        A21  A22  Target
# 0    0    0    1  17.078971    0       0
# 1    0    0    1  17.022384    0       0
# 2    0    0    0  17.024773    0       0
# 3    0    0    1  17.074995    0       0
# 4    0    0    1  17.072697    0       0
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (34281, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34281 entries, 0 to 34280
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      34281 non-null  int64
#  1   IV      34281 non-null  int64
#  2   A1      34281 non-null  int64
#  3   A2      32538 non-null  float64
#  4   A3      34281 non-null  int64
#  5   A4      34281 non-null  int64
#  6   A5      34281 non-null  int64
#  7   A6      34281 non-null  int64
#  8   A7      34281 non-null  int64
#  9   A8      34281 non-null  int64
#  10  A9      34281 non-null  int64
#  11  A10     34281 non-null  int64
#  12  A11     34281 non-null  int64
#  13  A12     34281 non-null  int64
#  14  A13     34281 non-null  int64
#  15  A14     34281 non-null  int64
#  16  A15     34281 non-null  float64
#  17  A16     34281 non-null  float64
#  18  A17     34281 non-null  int64
#  19  A18     34281 non-null  int64
#  20  A19     34281 non-null  int64
# ...

# %%
data['Target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['A11'].unique()
# Out:
# array([27], dtype=int64)

# %%
data['A13'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['A17'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # Total Unique Values:

# %%
data.nunique()
# Out:
# ID        34281
# IV         1897
# A1          777
# A2           24
# A3          606
# A4          169
# A5         1248
# A6         1639
# A7         1956
# A8          791
# A9         1368
# A10        1867
# A11           1
# A12        2230
# A13           2
# A14         156
# A15         102
# A16         102
# A17           2
# A18           2
# A19           2
# A20           2
# A21       34220
# A22           2
# Target        2
# dtype: int64

# %% [markdown]
# # Total Missing Values:

# %%
data.isnull().sum()
# Out:
# ID           0
# IV           0
# A1           0
# A2        1743
# A3           0
# A4           0
# A5           0
# A6           0
# A7           0
# A8           0
# A9           0
# A10          0
# A11          0
# A12          0
# A13          0
# A14          0
# A15          0
# A16          0
# A17          0
# A18          0
# A19          0
# A20          0
# A21          0
# A22          0
# Target       0
# dtype: int64

# %%
data.describe().T
# Out:
#           count          mean            std           min           25%  \
# ID      34281.0  1.979838e+06  638485.485227  1.058628e+06  1.464342e+06
# IV      34281.0  2.362520e+02    3326.574620 -2.999000e+03  2.000000e+00
# A1      34281.0  3.612637e+01     427.707021  0.000000e+00  0.000000e+00
# A2      32538.0  7.355185e+00       6.165307  0.000000e+00  2.000000e+00
# A3      34281.0  2.254307e+01     359.486291  0.000000e+00  0.000000e+00
# A4      34281.0  1.695371e+00      36.195759  0.000000e+00  0.000000e+00
# A5      34281.0  1.519590e+02    2274.087109  0.000000e+00  0.000000e+00
# A6      34281.0  2.744185e+02    4065.441226  0.000000e+00  0.000000e+00
# A7      34281.0  3.879336e+02    5443.804648  0.000000e+00  0.000000e+00
# A8      34281.0  3.648275e+01     375.931751  0.000000e+00  0.000000e+00
# A9      34281.0  1.329476e+02    4151.795360  0.000000e+00  0.000000e+00
# A10     34281.0  2.366471e+02    4528.960060  0.000000e+00  0.000000e+00
# ...

# %% [markdown]
# # Exploratory Data Analysis:

# %% [markdown]
# # Univariate Analysis:

# %%
data.hist(bins = 45, figsize = (18,15))
plt.show()

# %% [markdown]
# # Boxplot:

# %%
fig, ax = plt.subplots(ncols = 5, nrows = 5, figsize = (18,15))
index = 0
ax = ax.flatten()

for col, value in data.items():
    if col != 'type':
        sns.boxplot(y = col, data = data, ax = ax[index])
        index += 1
plt.tight_layout(pad = 0.3, w_pad = 0.4, h_pad = 4.0)

# %% [markdown]
# # Distribution plot:

# %%
fig, ax = plt.subplots(ncols = 5, nrows = 5, figsize = (18,15))
index = 0
ax = ax.flatten()

for col, value in data.items():
    if col != 'type':
        sns.distplot(value, ax = ax[index])
        index += 1
plt.tight_layout(pad = 0.5, w_pad = 0.7, h_pad = 5.0)

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['Target'])
# Out:
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %% [markdown]
# * In this graph we see that few people have a coronary heart disease as compare to the people does not having coronary heart disease.

# %%
plt.figure(figsize=(18,4))
sns.countplot(data['A2'])
data['A2'].value_counts()
# Out:
# 8.0     14091
# 2.0      7887
# 12.0     3738
# 4.0      2269
# 9.0      2259
# 3.0       419
# 52.0      413
# 0.0       314
# 10.0      269
# 14.0      190
# 16.0      179
# 6.0       113
# 13.0      111
# 5.0        96
# 15.0       80
# 17.0       61
# 11.0       29
# 30.0        6
# 20.0        5
# 26.0        2
# 22.0        2
# 7.0         2
# 18.0        2
# 28.0        1
# Name: A2, dtype: int64

# %% [markdown]
# * In this graph we see that more amount of A2 is at 8.

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A11'])
# Out:
# <AxesSubplot:xlabel='A11', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A13'])
data['A13'].value_counts()
# Out:
# 0    34218
# 1       63
# Name: A13, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A15'])
data['A15'].value_counts()
# Out:
#  0.99     2730
#  1.00     2416
# -99.00    2233
#  0.73     1743
#  0.98     1630
#           ...
#  0.29       21
#  0.39       21
#  0.03       20
#  0.04       12
#  0.01       10
# Name: A15, Length: 102, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A16'])
data['A16'].value_counts()
# Out:
#  0.99     2452
#  0.78     2161
# -99.00    2103
#  0.98     1824
#  0.97     1366
#           ...
#  0.05       24
#  0.04       23
#  0.02       20
#  0.21       18
#  0.06       16
# Name: A16, Length: 102, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A17'])
data['A17'].value_counts()
# Out:
# 0    27128
# 1     7153
# Name: A17, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A18'])
data['A18'].value_counts()
# Out:
# 0    34270
# 1       11
# Name: A18, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A19'])
data['A19'].value_counts()
# Out:
# 0    29758
# 1     4523
# Name: A19, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A20'])
data['A20'].value_counts()
# Out:
# 1    32991
# 0     1290
# Name: A20, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['A22'])
data['A22'].value_counts()
# Out:
# 0    34274
# 1        7
# Name: A22, dtype: int64

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A2', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A2', ylabel='count'>

# %% [markdown]
# * Beyond the 18 value of A2, the chances of getting heart disease are low.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A11', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A11', ylabel='count'>

# %% [markdown]
# * In this graph we se that at value 27 of A11 there is more people who does not have coronary heart disease .

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A13', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A13', ylabel='count'>

# %% [markdown]
# * In this graph we see that at value 0 of A13 there is more people who does not have coronary heart disease.

# %% [markdown]
# * At value of 1 there is few people who have coronary heart disease.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A15', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A15', ylabel='count'>

# %% [markdown]
# * In this graph we see that as the value of A15 increases there is people who having coronary heart disease is decreses.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A16', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A16', ylabel='count'>

# %% [markdown]
# * In this graph we also see that as the value of A16 increases the people having coronary heart disease is decreases.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A17', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A17', ylabel='count'>

# %% [markdown]
# * In this graph we see that there was 1:0.5 ratio of people who does not have coronary heart diesease and have coronary heart disease at values 0 and 1 of A17.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A18', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A18', ylabel='count'>

# %% [markdown]
# * At value 0 of A18 there is more people who does not have coronary heart disease.

# %% [markdown]
# * At value 1 of A18 there is no chances of having coronary heart disease.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A19', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A19', ylabel='count'>

# %% [markdown]
# * For A19, there is chances of heart disease in both cases.

# %%
plt.figure(figsize = (18,5))
sns.countplot(x = 'A20', hue = 'Target', data = data)
# Out:
# <AxesSubplot:xlabel='A20', ylabel='count'>

# %% [markdown]
# # Density Plot:

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['IV'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['IV'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('IV', fontsize = 16)
plt.title('Distribution Plot of IV with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of IV with Target')

# %% [markdown]
# * From the above graph we see that the density of people with heart disease is more at 0 and for rest all values there no increment

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A1'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A1'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A1', fontsize = 16)
plt.title('Distribution Plot of A1 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A1 with Target')

# %% [markdown]
# * For 0 value of A1 the density of people with heart disease is more as compared to people with no heart disease

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A2'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A2'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A2 ', fontsize = 16)
plt.title('Distribution Plot of A2 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A2 with Target')

# %% [markdown]
# * From the above graph people who have high chances of having heart disease are densly from A2=0 to 3 and A=5 to 10 as compare to people who having no heart disease.
# * People whose value value of A2 above 18 have no chances of having heart disease.

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A3'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A3'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A3', fontsize = 16)
plt.title('Distribution Plot of A3 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A3 with Target')

# %% [markdown]
# * From the above graph we see that the density of people with heart disease is more at 0 for A3 and above the 0 there is no chances of have heart disease.

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A4'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A4'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A4', fontsize = 16)
plt.title('Distribution Plot of A4 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A4 with Target')

# %% [markdown]
# * From the above graph we see that the density of people with no heart disease is more at 0 for A4 and above the 500 there is  chances of having heart disease.

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A5'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A5'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A5', fontsize = 16)
plt.title('Distribution Plot of A5 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A5 with Target')

# %% [markdown]
# * From the above graph we see that the density of people with heart disease is more at 0 for A3 and above the 0 there is no chances of have heart disease.

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A6'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A6'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A6', fontsize = 16)
plt.title('Distribution Plot of A6 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A6 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A7'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A7'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A7', fontsize = 16)
plt.title('Distribution Plot of A1 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A1 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A8'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A8'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A8', fontsize = 16)
plt.title('Distribution Plot of A8 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A8 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A9'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A9'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A9', fontsize = 16)
plt.title('Distribution Plot of A9 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A9 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A10'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A10'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A10', fontsize = 16)
plt.title('Distribution Plot of A10 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A10 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A11'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A11'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A11', fontsize = 16)
plt.title('Distribution Plot of A11 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A11 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A12'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A12'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A12', fontsize = 16)
plt.title('Distribution Plot of A12 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A12 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A13'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A13'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A13', fontsize = 16)
plt.title('Distribution Plot of A13 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A13 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A14'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A14'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A14', fontsize = 16)
plt.title('Distribution Plot of A14 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A14 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A15'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A15'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A15', fontsize = 16)
plt.title('Distribution Plot of A15 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A15 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A16'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A16'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A16', fontsize = 16)
plt.title('Distribution Plot of A16 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A16 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A17'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A17'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A17', fontsize = 16)
plt.title('Distribution Plot of A17 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A17 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A18'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A18'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A18', fontsize = 16)
plt.title('Distribution Plot of A18 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A18 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A19'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A19'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A19', fontsize = 16)
plt.title('Distribution Plot of A19 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A19 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A20'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A20'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A20', fontsize = 16)
plt.title('Distribution Plot of A20 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A20 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A21'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A21'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A21', fontsize = 16)
plt.title('Distribution Plot of A21 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A21 with Target')

# %%
plt.figure(figsize = (18,5))
sns.distplot(data['A22'][data['Target'] == 1], hist = False, color = 'red')
sns.distplot(data['A22'][data['Target'] == 0], hist = False, color = 'blue')
plt.xlabel('A22', fontsize = 16)
plt.title('Distribution Plot of A22 with Target', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Distribution Plot of A22 with Target')

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A2',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A2', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A11',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A11', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A13',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A13', ylabel='count'>

# %%
plt.figure(figsize=(18,4))
sns.countplot(x='A15',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A15', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A16',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A16', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A17',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A17', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A18',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A18', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A19',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A19', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A20',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A20', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A21',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A21', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='A22',hue='Target',data=data)
# Out:
# <AxesSubplot:xlabel='A22', ylabel='count'>

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # For IV

# %%
plt.figure(figsize=(25,25))
for i in enumerate(data.columns):
    plt.subplot(5,5,i[0]+1)
    sns.scatterplot(x='IV',y=i[1],hue='Target',data=data)

# %% [markdown]
# # For A21

# %%
plt.figure(figsize=(25,25))
for i in enumerate(data.columns):
    plt.subplot(5,5,i[0]+1)
    sns.scatterplot(x='A21',y=i[1],hue='Target',data=data)

# %% [markdown]
# # Heatmap:

# %%
plt.figure(figsize = (20,20))
plt.title('Correlation of all the Columns', fontsize = 20)
sns.heatmap(data.corr(), annot = True, vmin = -1, vmax = 1, center = 0, fmt = '.1g', linewidths = 1, linecolor = 'white', 
            square = True, cmap ='RdBu')
# Out:
# <AxesSubplot:title={'center':'Correlation of all the Columns'}>

# %%
data.drop(columns=['A11'], inplace=True)

# %% [markdown]
# # Missing value imputation:

# %%
from sklearn.impute import SimpleImputer as smpt

# %%
imputer=smpt(missing_values=np.nan,strategy='median')
data['A2']=imputer.fit_transform(data['A2'].values.reshape(-1,1))

# %%
impute=smpt(missing_values=-99.0,strategy='median')
data['A15']=impute.fit_transform(data['A15'].values.reshape(-1,1))

# %%
data['A16']=impute.fit_transform(data['A16'].values.reshape(-1,1))

# %%
def outlier(value):
    if value<lower:
        return lower
    elif value>upper:
        return upper
    else:
        return value

# %%
for i in data.columns:
    df=data[i].describe()
    q1=df[4]
    q3=df[6]
    iqr=q3-q1
    lower=q1-iqr*1.5
    upper=q3+iqr*1.5
    data[i]=data[i].apply(outlier)

# %% [markdown]
# # Preprocessing Data:

# %%
X = data.drop(columns = ['Target'])
y = data['Target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (23996, 23)
# (23996,)
# (10285, 23)
# (10285,)

# %% [markdown]
# # Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score

lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = lr.predict(x_train)
y_pred_test  = lr.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_test, y_test))
# Out:
# Training accuracy : 0.6714035672612102
# Testing accuracy  : 0.6686436558094312

# %% [markdown]
# # Decision Tree Classifier:

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtc_train = dtc.predict(x_train)
y_pred_dtc_test  = dtc.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_dtc_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_dtc_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy  : 0.8507535245503159

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred_svm_train = svm.predict(x_train)
y_pred_svm_test  = svm.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_svm_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_svm_test, y_test))
# Out:
# Training accuracy : 0.6714035672612102
# Testing accuracy  : 0.6686436558094312

# %% [markdown]
# # Random Forest Clssifier:

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc_train = rfc.predict(x_train)
y_pred_rfc_test  = rfc.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_rfc_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_rfc_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy  : 0.8995624696159455

# %% [markdown]
# # Hyper Parameter tunning:

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

# %%
params = {
    'n_estimators':[50,100,150,200,250,300,350,400], 
    'max_depth': [5,6,7,8,9], 
    'min_samples_leaf': [1,2,3,4,5], 
    'criterion': ["gini", "entropy"] 
}

from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
model = RandomForestClassifier(random_state = 42)
grid_search_rf = GridSearchCV(estimator = model, 
                              param_grid = params, 
                              cv = 5, 
                              n_jobs = -1, 
                              verbose = 1, 
                              scoring = "accuracy")

grid_search_rf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 400 candidates, totalling 2000 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'n_estimators': [50, 100, 150, 200, 250, 300, 350,
#                                           400]},
#              scoring='accuracy', verbose=1)

# %%
print("Best parameters for the model :", grid_search_rf.best_params_)
print("Best score for the model      :", grid_search_rf.best_score_)
# Out:
# Best parameters for the model : {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'n_estimators': 200}
# Best score for the model      : 0.8842309595749114

# %%
train_rfc_pred = grid_search_rf.predict(x_train)
test_rfc_pred  = grid_search_rf.predict(x_test)

print("Train Accuracy : ", accuracy_score(y_train, train_rfc_pred))
print("Test Accuracy  : ", accuracy_score(y_test, test_rfc_pred))
# Out:
# Train Accuracy :  0.90135855975996
# Test Accuracy  :  0.8798249878463782

# %%
cm_test = confusion_matrix(y_test, test_rfc_pred)
print(cm_test)
# Out:
# [[6272  605]
#  [ 631 2777]]

# %%
print('Classificatiwon report for train data is : \n',
      classification_report(y_train, train_rfc_pred))

print('\n')
print('Classification report for test data is : \n',
      classification_report(y_test, test_rfc_pred))
# Out:
# Classificatiwon report for train data is :
#                precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93     16111
#            1       0.85      0.84      0.85      7885
#
#     accuracy                           0.90     23996
#    macro avg       0.89      0.89      0.89     23996
# weighted avg       0.90      0.90      0.90     23996
#
#
#
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      6877
#            1       0.82      0.81      0.82      3408
#
#     accuracy                           0.88     10285
#    macro avg       0.86      0.86      0.86     10285
# weighted avg       0.88      0.88      0.88     10285

# %%
importance = grid_search_rf.best_estimator_.feature_importances_
feature_imp = pd.Series(importance, index = X.columns).sort_values(ascending = False)
feature_imp
sns.set(style = 'darkgrid', font_scale = 1.2)
plt.figure(figsize = (15, 8))
# Visualize the Importance Creating a bar plot
sns.barplot(x = feature_imp, y = feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title('Random Forest - Feature Importance', weight = 'bold', fontsize = 16)
plt.show()
